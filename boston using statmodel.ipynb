# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
# Out:
# C:\Users\SMIT\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split 
data = datasets.load_boston()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
target = pd.DataFrame(data.target, columns=["MEDV"])

# %%
print data.DESCR
print data.feature_names
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
X = df["CRIM"]
y = target["MEDV"]
model1 = sm.OLS(y, X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     26.44
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           3.89e-07
# Time:                        10:49:26   Log-Likelihood:                -2320.2
# No. Observations:                 506   AIC:                             4642.
# Df Residuals:                     505   BIC:                             4647.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CRIM           0.5830      0.113      5.142      0.000       0.360       0.806
# ...

# %%
X = df["ZN"]
y = target["MEDV"]
model2 = sm.OLS(y, X).fit()
predictions = model2.predict(X)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     195.5
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           8.88e-38
# Time:                        10:49:28   Log-Likelihood:                -2250.3
# No. Observations:                 506   AIC:                             4503.
# Df Residuals:                     505   BIC:                             4507.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ZN             0.4959      0.035     13.980      0.000       0.426       0.566
# ...

# %%
X = df["INDUS"]
y = target["MEDV"]
model3 = sm.OLS(y, X).fit()
predictions = model3.predict(X)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     466.3
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           9.55e-74
# Time:                        10:49:33   Log-Likelihood:                -2167.6
# No. Observations:                 506   AIC:                             4337.
# Df Residuals:                     505   BIC:                             4341.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# INDUS          1.2894      0.060     21.595      0.000       1.172       1.407
# ...

# %%
X = df["CHAS"]
y = target["MEDV"]
model4 = sm.OLS(y, X).fit()
predictions = model4.predict(X)
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     52.69
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           1.48e-12
# Time:                        10:49:33   Log-Likelihood:                -2308.0
# No. Observations:                 506   AIC:                             4618.
# Df Residuals:                     505   BIC:                             4622.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CHAS          28.4400      3.918      7.259      0.000      20.743      36.137
# ...

# %%
X = df["NOX"]
y = target["MEDV"]
model5 = sm.OLS(y, X).fit()
predictions = model5.predict(X)
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     1626.
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          5.53e-160
# Time:                        10:49:34   Log-Likelihood:                -1968.9
# No. Observations:                 506   AIC:                             3940.
# Df Residuals:                     505   BIC:                             3944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NOX           37.5110      0.930     40.319      0.000      35.683      39.339
# ...

# %%
X = df["RM"]
y = target["MEDV"]
model6 = sm.OLS(y, X).fit()
predictions = model6.predict(X)
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     4615.
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          3.74e-256
# Time:                        10:49:35   Log-Likelihood:                -1747.1
# No. Observations:                 506   AIC:                             3496.
# Df Residuals:                     505   BIC:                             3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             3.6534      0.054     67.930      0.000       3.548       3.759
# ...

# %%
X = df["AGE"]
y = target["MEDV"]
model7 = sm.OLS(y, X).fit()
predictions = model7.predict(X)
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     915.1
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          1.85e-115
# Time:                        10:49:36   Log-Likelihood:                -2071.5
# No. Observations:                 506   AIC:                             4145.
# Df Residuals:                     505   BIC:                             4149.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AGE            0.2636      0.009     30.250      0.000       0.246       0.281
# ...

# %%
X = df["DIS"]
y = target["MEDV"]
model8 = sm.OLS(y, X).fit()
predictions = model8.predict(X)
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     1380.
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          1.52e-146
# Time:                        10:49:36   Log-Likelihood:                -1999.8
# No. Observations:                 506   AIC:                             4002.
# Df Residuals:                     505   BIC:                             4006.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# DIS            4.7985      0.129     37.149      0.000       4.545       5.052
# ...

# %%
X = df["RAD"]
y = target["MEDV"]
model9 = sm.OLS(y, X).fit()
predictions = model9.predict(X)
model9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     266.2
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           2.25e-48
# Time:                        10:49:37   Log-Likelihood:                -2226.0
# No. Observations:                 506   AIC:                             4454.
# Df Residuals:                     505   BIC:                             4458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RAD            1.1068      0.068     16.316      0.000       0.974       1.240
# ...

# %%
X = df["TAX"]
y = target["MEDV"]
model10 = sm.OLS(y, X).fit()
predictions = model10.predict(X)
model10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     830.5
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          1.03e-108
# Time:                        10:49:38   Log-Likelihood:                -2087.0
# No. Observations:                 506   AIC:                             4176.
# Df Residuals:                     505   BIC:                             4180.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TAX            0.0435      0.002     28.818      0.000       0.040       0.046
# ...

# %%
X = df["PTRATIO"]
y = target["MEDV"]
model11 = sm.OLS(y, X).fit()
predictions = model11.predict(X)
model11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     2088.
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          1.51e-181
# Time:                        10:49:39   Log-Likelihood:                -1919.1
# No. Observations:                 506   AIC:                             3840.
# Df Residuals:                     505   BIC:                             3844.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PTRATIO        1.1752      0.026     45.698      0.000       1.125       1.226
# ...

# %%
X = df["B"]
y = target["MEDV"]
model12 = sm.OLS(y, X).fit()
predictions = model12.predict(X)
model12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     3148.
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):          3.99e-219
# Time:                        10:49:39   Log-Likelihood:                -1832.5
# No. Observations:                 506   AIC:                             3667.
# Df Residuals:                     505   BIC:                             3671.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# B              0.0614      0.001     56.105      0.000       0.059       0.064
# ...

# %%
X = df["LSTAT"]
y = target["MEDV"]
model13 = sm.OLS(y, X).fit()
predictions = model13.predict(X)
model13.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     410.9
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):           2.71e-67
# Time:                        10:49:40   Log-Likelihood:                -2182.4
# No. Observations:                 506   AIC:                             4367.
# Df Residuals:                     505   BIC:                             4371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# LSTAT          1.1221      0.055     20.271      0.000       1.013       1.231
# ...

# %%
X = df
y = target["MEDV"]
model14 = sm.OLS(y, X).fit()
predictions = model14.predict(X)
model14.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     891.1
# Date:                Sun, 07 Oct 2018   Prob (F-statistic):               0.00
# Time:                        10:51:01   Log-Likelihood:                -1523.8
# No. Observations:                 506   AIC:                             3074.
# Df Residuals:                     493   BIC:                             3129.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CRIM          -0.0916      0.034     -2.675      0.008      -0.159      -0.024
# ...

# %%
print 'CRIM =',model1.rsquared
print 'ZN =',model2.rsquared
print 'INDUS =',model3.rsquared
print 'CHAS =',model4.rsquared
print 'NOX =',model5.rsquared
print 'RM =',model6.rsquared
print 'AGE =',model7.rsquared
print 'DIS =',model8.rsquared
print 'RAD =',model9.rsquared
print 'TAX =',model10.rsquared
print 'PTRATIO =',model11.rsquared
print 'B =',model12.rsquared
print 'LSTAT =',model13.rsquared
# Out:
# CRIM = 0.0497522829013
# ZN = 0.279035446343
# INDUS = 0.480091501177
# CHAS = 0.0944815999822
# NOX = 0.762977450314
# RM = 0.901357866172
# AGE = 0.644387176619
# DIS = 0.732100256156
# RAD = 0.345172579171
# TAX = 0.621855719873
# PTRATIO = 0.805269324242
# B = 0.861749125172
# LSTAT = 0.448649254126

# %%
df = df[['ZN','CHAS','RM','DIS','PTRATIO','B','LSTAT']]
X = df
y = target["MEDV"]
model15 = sm.OLS(y, X).fit()
predictions = model15.predict(X)
model15.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     1610.
# Date:                Sat, 27 Oct 2018   Prob (F-statistic):               0.00
# Time:                        10:43:35   Log-Likelihood:                -1533.4
# No. Observations:                 506   AIC:                             3081.
# Df Residuals:                     499   BIC:                             3110.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ZN             0.0382      0.014      2.761      0.006       0.011       0.065
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.2)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape
# Out:
# (404, 7) (404, 1)
# (102, 7) (102, 1)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.7137533686937485

# %%
from sklearn.metrics import mean_squared_error,r2_score
print ("MSE",mean_squared_error(y_test,predictions))
print ("Variance Score",r2_score(y_test,predictions))
import matplotlib.pyplot as plt
# Out:
# ('MSE', 24.83199761467049)
# ('Variance Score', 0.7137533686937485)

# %%
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

# %%
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics
# Out:
# C:\Users\SMIT\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
scores = cross_val_score(model, df, y, cv=5)
print (scores)
# Out:
# [0.67888386 0.70139853 0.60963812 0.15465102 0.13454821]

# %%
predictions = cross_val_predict(model, df, y, cv=5)
plt.scatter(y ,predictions)
plt.show()

# %%
metrics.r2_score(y, predictions)
# Out:
# 0.6056016088157619
